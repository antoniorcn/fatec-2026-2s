# %%
#  !python -m spacy download pt_core_news_sm

# %%
import matplotlib.pyplot as plt

# %%
import spacy

# %%
import numpy as np

# %%
nlp = spacy.load("pt_core_news_sm")

# %%
X = np.linspace(0, 10, 20)

# %%
X
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
temp = np.random.random(20)

# %%
temp
# Out:
# array([0.13447565, 0.36591542, 0.2187359 , 0.68392045, 0.89966152,
#        0.36653087, 0.24932867, 0.2966968 , 0.63217766, 0.36673208,
#        0.54696996, 0.55694235, 0.4564219 , 0.88437599, 0.11211647,
#        0.81995589, 0.05547836, 0.31265008, 0.44802031, 0.34530949])

# %%
Y = X * temp
Y
# Out:
# array([0.        , 0.19258706, 0.23024832, 1.0798744 , 1.89402426,
#        0.96455491, 0.7873537 , 1.09309346, 2.66180067, 1.73715195,
#        2.87878927, 3.22440306, 2.88266461, 6.0509936 , 0.82612133,
#        6.47333597, 0.46718615, 2.79739544, 4.24440295, 3.45309486])

# %%
fig, ax = plt.subplots(1, 2)
ax[0].plot(X, Y, color="green", linestyle="-.", linewidth=1, alpha=0.9, label="Teste")
# ax[0].plot(Y, X, color="red", linestyle="-.", linewidth=1, alpha=0.9, label="Teste 2")
ax[0].grid(True, color="red", linestyle="--", linewidth=1, alpha=0.1)
ax[0].set_xlabel("Ano Corrente")
ax[0].set_ylabel("Lucro")
ax[0].text( 8, 0.5, "Pandemia")
ax[0].set_title("Lucro do ano atual")
# ax[0].set_xlim(2.5, 7.5)
# ax[0].set_ylim(2, 8)
ax[0].axhline(6.5)
ax[0].axvline(3)
ax[0].legend()
ax[1].barh(X, Y)
ax[1].set_xlabel("Meses")
ax[1].set_ylabel("Volume de Vendas")
ax[1].grid(True)
plt.tight_layout(pad=2)
plt.show()

# %%
pessoas = np.random.randint(12, 98, 100)
pessoas.shape
# Out:
# (100,)

# %%
plt.hist(pessoas, bins=10, range=(30, 98), rwidth=0.8)
# Out:
# (array([ 3.,  7.,  7., 12.,  6.,  5., 13., 11.,  5., 11.]),
#  array([30. , 36.8, 43.6, 50.4, 57.2, 64. , 70.8, 77.6, 84.4, 91.2, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
palavras = [100, 150, 200, 250, 300]
palavras_unicas = [65, 90, 110, 130, 145]

plt.scatter(palavras, palavras_unicas, s=30, color="blue")
plt.xlabel("Quantidade de palavras")
plt.ylabel("Palavras únicas")
plt.title("Tamanho do texto × Vocabulário")
plt.show()

# %%
activities = ['eat', 'sleep', 'work', 'studing', 'play'] 

slices = [3, 6, 6, 6, 3] 

colors = ['yellow', 'blue', 'red', 'brown', 'green'] 
  
# plotting the pie chart 
plt.pie( slices, labels = activities,
		colors=colors, startangle=0,
		shadow = True, 
		explode = (0, 0.2, 0, 0, 0), 
		radius = 1.2, autopct = '%1.1f%%') 
plt.legend(loc="upper right") 
plt.show()
