# %%
#  !python -m spacy download pt_core_news_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting pt-core-news-sm==3.8.0
#   Downloading pt_core_news_sm-3.8.0-py3-none-any.whl (13.0 MB)
#      ---------------------------------------- 0.0/13.0 MB ? eta -:--:--
#      ---- ----------------------------------- 1.3/13.0 MB 7.6 MB/s eta 0:00:02
#      --------- ------------------------------ 3.1/13.0 MB 7.9 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.5/13.0 MB 9.4 MB/s eta 0:00:01
#      ------------------------- -------------- 8.4/13.0 MB 10.2 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/13.0 MB 10.6 MB/s eta 0:00:01
#      ---------------------------------------- 13.0/13.0 MB 11.1 MB/s  0:00:01
# [+] Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %%
import matplotlib.pyplot as plt

# %%
import spacy

# %%
import numpy as np

# %%
nlp = spacy.load("pt_core_news_sm")

# %%
X = np.linspace(0, 10, 20)

# %%
X
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
temp = np.random.random(20)

# %%
temp
# Out:
# array([0.94551967, 0.5738005 , 0.8037758 , 0.49672965, 0.84708963,
#        0.98000786, 0.53400464, 0.16976359, 0.61973408, 0.96101388,
#        0.58518368, 0.35819313, 0.18509711, 0.09268544, 0.60799182,
#        0.8968922 , 0.15830847, 0.11351294, 0.38288843, 0.1596807 ])

# %%
Y = X * temp
Y
# Out:
# array([0.        , 0.30200026, 0.84607979, 0.78430997, 1.7833466 ,
#        2.57896805, 1.68633044, 0.6254448 , 2.60940665, 4.55217101,
#        3.0799141 , 2.07374969, 1.16903436, 0.63416357, 4.4799397 ,
#        7.08072792, 1.33312398, 1.01564211, 3.62736404, 1.59680702])

# %%
fig, ax = plt.subplots(1, 2)
ax[0].plot(X, Y)
ax[1].plot(Y, X)
plt.show()
